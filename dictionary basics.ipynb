# %%
my_dict = {'key1': 'value1', 'key2': 'value2'}

# %%
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
my_dict['key1']
# Out:
# 'value1'

# %%
prices_lookup = {'apple': 2.99,'oranges':1.99,'milk':5.80}

# %%
prices_lookup['apple']
# Out:
# 2.99

# %%
d = {'k1': 123, 'k2':[0,1,2],'k3':{'insidekey':100}}

# %%
d
# Out:
# {'k1': 123, 'k2': [0, 1, 2], 'k3': {'insidekey': 100}}

# %%
d['k2'][2]
# Out:
# 2

# %%
d['k3']
# Out:
# {'insidekey': 100}

# %%
d['k3']['insidekey']
# Out:
# 100

# %%
d = {'key1':['a','b','c']}

# %%
d
# Out:
# {'key1': ['a', 'b', 'c']}

# %%
my_list= d['key1']

# %%
my_list
# Out:
# ['a', 'b', 'c']

# %%
letter = my_list[2]

# %%
letter
# Out:
# 'c'

# %%
letter.upper()
# Out:
# 'C'

# %%
d
# Out:
# {'key1': ['a', 'b', 'c']}

# %%
d['key1'][2].upper()
# Out:
# 'C'

# %%
d = {'K1':100, 'k2':200}

# %%
d
# Out:
# {'K1': 100, 'k2': 200}

# %%
d['k3'] =300

# %%
d
# Out:
# {'K1': 100, 'k2': 200, 'k3': 300}

# %%
d['K1'] = 'NEW VALUE'

# %%
d
# Out:
# {'K1': 'NEW VALUE', 'k2': 200, 'k3': 300, 'k1': 'NEW VALUE'}

# %%
d= {'K1': 100, 'k2': 200, 'k3': 300}

# %%
d.keys()
# Out:
# dict_keys(['K1', 'k2', 'k3'])

# %%
d.values()
# Out:
# dict_values([100, 200, 300])

# %%
d.items()
# Out:
# dict_items([('K1', 100), ('k2', 200), ('k3', 300)])
